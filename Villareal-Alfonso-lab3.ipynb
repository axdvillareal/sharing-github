# %% [markdown]
# 162118
#
# Villareal
#
# 5 BS ITE

# %%
social_graph = {
    "@bongolpoc":{"first_name":"Joselito",
                  "last_name":"Olpoc",
                  "following":[
                  ]
    },
    "@joaquin":  {"first_name":"Joaquin",
                  "last_name":"Gonzales",
                  "following":[
                      "@chums","@jobenilagan"
                  ]
    },
    "@chums" : {"first_name":"Matthew",
                "last_name":"Uy",
                "following":[
                    "@bongolpoc","@miketan","@rudyang","@joeilagan"
                ]
    },
    "@jobenilagan":{"first_name":"Joben",
                   "last_name":"Ilagan",
                   "following":[
                    "@eeebeee","@joeilagan","@chums","@joaquin"
                   ]
    },
    "@joeilagan":{"first_name":"Joe",
                  "last_name":"Ilagan",
                  "following":[
                    "@eeebeee","@jobenilagan","@chums"
                  ]
    },
    "@eeebeee":  {"first_name":"Elizabeth",
                  "last_name":"Ilagan",
                  "following":[
                    "@jobenilagan","@joeilagan"
                  ]
    },
}

def relationship_status(from_member,to_member):
    followingList = (social_graph[to_member]["following"])
    isFollowing = False
    isFollowed = False
    #print (followingList)
    for x in followingList:
        if (x == str(from_member)):
            #to_member is following from_member
            isFollowing = True
    followingList = (social_graph[from_member]["following"])
    #print (followingList)
    for x in followingList:
        if (x == str(to_member)):
            isFollowed = True
             #from_member is following to_member
    if isFollowing & isFollowed:
        print ("friends")
    elif isFollowing or isFollowed:
        if isFollowed == True:
            print ("follows")
        if isFollowing == True:
            print ("followed by")
    else:
        print("")
relationship_status("@chums","@jobenilagan")
relationship_status("@jobenilagan","@joeilagan")
relationship_status("@bongolpoc","@chums")
relationship_status("@bongolpoc","@jobenilagan")
relationship_status("@bongolpoc","@chums")
relationship_status("@chums","@joeilagan")
relationship_status("@joeilagan","@chums")
# Out:
# followed by
# friends
# followed by
#
# followed by
# friends
# friends

# %%
board1 = [
['X','X','O'],
['O','X','O'],
['O','','X'],
]

board2 = [
['X','X','O'],
['O','X','O'],
['','O','X'],
]

board3 = [
['O','X','O'],
['','O','X'],
['X','X','O'],
]

board4 = [
['X','X','X'],
['O','X','O'],
['O','','O'],
]

board5 = [
['X','X','O'],
['O','X','O'],
['X','','O'],
]

board6 = [
['X','X','O'],
['O','X','O'],
['X','',''],
]

def get_winner(board):
    winner = ""
    xPoints = 0
    oPoints = 0
    x=0
    y=0
    #horizontal
    while y < 3:
        while x < 3:
            #print (board[y][x])
            if board[y][x] == "X":
                xPoints+=1
            if board[y][x] == "O":
                oPoints+=1
            if xPoints == 3:
                winner = "X"
            if oPoints == 3:
                winner = "O"
            x+=1
        x = 0
        xPoints = 0
        oPoints = 0
        y+=1
    #vertical
    x=0
    y=0
    while x < 3:
        while y < 3:
            if board[y][x] == "X":
                xPoints+=1
            if board[y][x] == "O":
                oPoints+=1
            if xPoints == 3:
                winner = "X"
            if oPoints == 3:
                winner = "O"
            y+=1
        y = 0
        xPoints = 0
        oPoints = 0
        x+=1
    #diagonal
    x = 0
    y = 0
    while x < 3:
        #print (board[x][x])
        if board[x][x] == "X":
            xPoints+=1
        if board[x][x] == "O":
            oPoints+=1
        if xPoints == 3:
            winner = "X"
        if oPoints == 3:
            winner = "O"
        x+=1
    x = 0
    xPoints = 0
    oPoints = 0
    y=2
    #diagonal 2
    while x < 3:
        while y >= 0:
            #print (board[x][y])
            if board[x][y] == "X":
                xPoints+=1
            if board[x][y] == "O":
                oPoints+=1
            if xPoints == 3:
                winner = "X"
            if oPoints == 3:
                winner = "O"
            y-=1
        x+=1
    x = 0
    xPoints = 0
    oPoints = 0
    print(winner)
get_winner(board3)
# Out:
# O

# %% [markdown]
# #

# %%
locations = {
    "admu":{
        "name":"Ateneo de Manila University",
        "latitude":14.6394557,
        "longitude":121.0758975
    },
    "upd":{
        "name":"University of the Philippines-Diliman Campus",
        "latitude":14.6538519,
        "longitude":121.0663348
    },
    "dlsu":{
        "name":"De La Salle University-Taft",
        "latitude":14.5647346,
        "longitude":120.9909876

    }, # <-- Note that Python does not complain about this extra comma. This is perfectly okay.
       #     The creators of Python saw that dictionaries tend to be changed a lot, so allowing this is a
       #     convenience for developers who need to add elements when needed.
}

legs = {
     ("upd","admu"):{
         "travel_time_mins":10
     },
     ("admu","dlsu"):{
         "travel_time_mins":35
     },
     ("dlsu","upd"):{
         "travel_time_mins":55
     },
       }

def eta(source,destination):
    arr = ["upd","admu","dlsu","upd","admu","dlsu"]
    ETA = 0
    start = int(arr.index(source))
    end = int(arr.index(destination))
    if start >= end:
        arr.reverse()
        end = 5-arr.index(destination)
        arr.reverse()
    for x in range(start, end):
        ETA += legs[arr[x],arr[x+1]]["travel_time_mins"]
    return(ETA)

source = input ("Enter source: ")
destination = input ("Enter destination: ")
eta(source,destination)
# Out:
# Enter source: dlsu
# Enter destination: admu
# 65
